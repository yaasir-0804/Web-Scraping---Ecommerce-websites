# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "https://www.flipkart.com/audio-video/headphones/pr?sid=0pm%2Cfcn&otracker=categorytree&p%5B%5D=facets.connectivity%255B%255D%3DBluetooth&fm=neo%2Fmerchandising&iid=M_5f8e6917-1340-48c7-a09b-e1bb175bab53_2_372UD5BXDFYS_MC.R08R6GB1Q1BI&otracker=hp_rich_navigation_2_2.navigationCard.RICH_NAVIGATION_Electronics%7EAudio%7EBluetooth%2BHeadphones_R08R6GB1Q1BI&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&cid=R08R6GB1Q1BI&sort=price_desc"

# %%
allow = requests.get(url)

# %%
allow
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
product_name = soup.select(".s1Q9rs")

# %%
product_name
# Out:
# [<a class="s1Q9rs" href="/beats-mrj72zm-a-bluetooth-headset/p/itm87b842c3d681e?pid=ACCFY7EHHYS5HDZG&amp;lid=LSTACCFY7EHHYS5HDZGE6CCJC&amp;marketplace=FLIPKART&amp;store=0pm%2Ffcn&amp;srno=b_1_1&amp;otracker=browse&amp;otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&amp;fm=organic&amp;iid=4078a378-152d-4528-be9a-51f6d6a39865.ACCFY7EHHYS5HDZG.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=rg9619vjk00000001653908036589" rel="noopener noreferrer" target="_blank" title="Beats MRJ72ZM/A Bluetooth Headset">Beats MRJ72ZM/A Bluetooth Headset</a>,
# ...

# %%
product_title =[]

# %%
product_link =[]

# %%
for item in product_name:
    link = "https://www.flipkart.com/"
    product_link.append(link)
    product_title.append(item.text)

# %%
product_title
# Out:
# ['Beats MRJ72ZM/A Bluetooth Headset',
#  'APPLE Airpods Pro with MagSafe Charging Case Bluetooth ...',
#  'Bose Quietcomfort 35 II Active noise cancellation enabl...',
#  'APPLE Airpods (3rd Generation) Bluetooth Headset',
#  'SONY WH-XB910N Active Noise Cancellation enabled Blueto...',
#  'Soundcore by Anker Liberty Air 2 Pro With Active Noise ...',
#  'Apple AirPods with Charging Case Bluetooth Headset with...',
#  'SAMSUNG Galaxy Buds 2 Bluetooth Headset',
#  'Soundcore by Anker Liberty Air 2 Pro With Active Noise ...',
#  'Soundcore by Anker Life Q35 With Targeted Active Noise ...',
#  'Soundcore by Anker Space NC Active noise cancellation e...',
#  'Soundcore by Anker Liberty 2 Pro with In-ear Studio Per...',
#  'Jabra Elite 4 Active with Active Noise Cancellation Blu...',
#  'Soundcore by Anker Life Q35 With Targeted Active Noise ...',
#  'Jabra Elite 4 Active with Active Noise Cancellation Blu...',
#  'Soundcore by Anker Liberty Air 2 Pro With Active Noise ...',
# ...

# %%
Des_list = soup.select("._3Djpdu")

# %%
Des_list
# Out:
# [<div class="_3Djpdu">Ivory, On the Ear</div>,
#  <div class="_3Djpdu">White, True Wireless</div>,
#  <div class="_3Djpdu">Silver, On the Ear</div>,
#  <div class="_3Djpdu">White, True Wireless</div>,
#  <div class="_3Djpdu">Blue, On the Ear</div>,
#  <div class="_3Djpdu">White, True Wireless</div>,
#  <div class="_3Djpdu">White, True Wireless</div>,
#  <div class="_3Djpdu">Graphite, True Wireless</div>,
#  <div class="_3Djpdu">Pink, True Wireless</div>,
#  <div class="_3Djpdu">Pink, On the Ear</div>,
#  <div class="_3Djpdu">Black, Grey, On the Ear</div>,
#  <div class="_3Djpdu">White, True Wireless</div>,
#  <div class="_3Djpdu">Black, True Wireless</div>,
#  <div class="_3Djpdu">Blue, On the Ear</div>,
#  <div class="_3Djpdu">Navy, True Wireless</div>,
#  <div class="_3Djpdu">Black, True Wireless</div>,
#  <div class="_3Djpdu">Blue, True Wireless</div>,
#  <div class="_3Djpdu">White, True Wireless</div>,
#  <div class="_3Djpdu">Mystic Black, True Wireless</div>,
# ...

# %%
Description =[]
Des_link=[]

# %%
for item in Des_list:
    link : "https://www.flipkart.com"
    Description.append(item.text)
    Des_link.append(item.text)

# %%
Description
# Out:
# ['Ivory, On the Ear',
#  'White, True Wireless',
#  'Silver, On the Ear',
#  'White, True Wireless',
#  'Blue, On the Ear',
#  'White, True Wireless',
#  'White, True Wireless',
#  'Graphite, True Wireless',
#  'Pink, True Wireless',
#  'Pink, On the Ear',
#  'Black, Grey, On the Ear',
#  'White, True Wireless',
#  'Black, True Wireless',
#  'Blue, On the Ear',
#  'Navy, True Wireless',
#  'Black, True Wireless',
#  'Blue, True Wireless',
#  'White, True Wireless',
#  'Mystic Black, True Wireless',
#  'Black, True Wireless',
#  'Blue, On the Ear',
#  'Black, True Wireless',
#  'Black, True Wireless',
#  'Clearly White, True Wireless',
#  'Black, On the Ear',
#  'Silver, On the Ear',
#  'Blue, On the Ear',
#  'White, True Wireless',
#  'Black, True Wireless',
#  'Black, True Wireless',
#  'Black, On the Ear',
#  'Blue, True Wireless',
#  'Black, Grey, True Wireless',
#  'Pearl White, In the Ear',
#  'White, True Wireless',
#  'Obsidian Black, In the Ear',
#  'Black, True Wireless',
# ...

# %%
price_list = soup.select("._30jeq3")

# %%
price_list
# Out:
# [<div class="_30jeq3">₹25,472</div>,
#  <div class="_30jeq3">₹21,900</div>,
#  <div class="_30jeq3">₹21,990</div>,
#  <div class="_30jeq3">₹18,500</div>,
#  <div class="_30jeq3">₹14,990</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹12,499</div>,
#  <div class="_30jeq3">₹11,999</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹10,999</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹6,999</div>,
#  <div class="_30jeq3">₹7,990</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹6,699</div>,
#  <div class="_30jeq3">₹6,999</div>,
#  <div class="_30jeq3">₹6,999</div>,
#  <div class="_30jeq3">₹7,999</div>,
#  <div class="_30jeq3">₹7,999</div>,
#  <div class="_30jeq3">₹7,999</div>,
# ...

# %%
price = []

# %%
for item in price_list:
    price.append(item.text)

# %%
price
# Out:
# ['₹25,472',
#  '₹21,900',
#  '₹21,990',
#  '₹18,500',
#  '₹14,990',
#  '₹9,999',
#  '₹12,499',
#  '₹11,999',
#  '₹9,999',
#  '₹9,999',
#  '₹10,999',
#  '₹9,999',
#  '₹9,999',
#  '₹9,999',
#  '₹9,999',
#  '₹9,999',
#  '₹9,999',
#  '₹6,999',
#  '₹7,990',
#  '₹9,999',
#  '₹6,699',
#  '₹6,999',
#  '₹6,999',
#  '₹7,999',
#  '₹7,999',
#  '₹7,999',
#  '₹7,999',
#  '₹6,999',
#  '₹5,990',
#  '₹5,999',
#  '₹7,999',
#  '₹5,999',
#  '₹4,999',
#  '₹4,999',
#  '₹4,999',
#  '₹4,999',
#  '₹4,999',
#  '₹7,999',
#  '₹4,999',
#  '₹4,990']

# %%
import pandas as pd

# %%
product = pd.DataFrame(product_title,columns=["Headphone_Brand"])

# %%
product['price']=price

# %%
product['Description'] = Description

# %%
product
# Out:
#                                       Headphone_Brand    price  \
# 0                   Beats MRJ72ZM/A Bluetooth Headset  ₹25,472
# 1   APPLE Airpods Pro with MagSafe Charging Case B...  ₹21,900
# 2   Bose Quietcomfort 35 II Active noise cancellat...  ₹21,990
# 3    APPLE Airpods (3rd Generation) Bluetooth Headset  ₹18,500
# 4   SONY WH-XB910N Active Noise Cancellation enabl...  ₹14,990
# 5   Soundcore by Anker Liberty Air 2 Pro With Acti...   ₹9,999
# 6   Apple AirPods with Charging Case Bluetooth Hea...  ₹12,499
# 7             SAMSUNG Galaxy Buds 2 Bluetooth Headset  ₹11,999
# 8   Soundcore by Anker Liberty Air 2 Pro With Acti...   ₹9,999
# 9   Soundcore by Anker Life Q35 With Targeted Acti...   ₹9,999
# 10  Soundcore by Anker Space NC Active noise cance...  ₹10,999
# 11  Soundcore by Anker Liberty 2 Pro with In-ear S...   ₹9,999
# 12  Jabra Elite 4 Active with Active Noise Cancell...   ₹9,999
# 13  Soundcore by Anker Life Q35 With Targeted Acti...   ₹9,999
# ...

# %%
product.to_csv("VAC_ASSIGNMENT.csv")
